# %%
import pandas as pd
import numpy as np

# %%
# Import and Preprocess Dataset

df = pd.read_csv('Cleaned_Lung_Cancer_dataset.csv')

df = df.drop('Days from Diagnosis to Treatment', axis=1)
df = df[(df['Cancer Cell Type'] != 'Not Lung Cancer') &
        (df['Cause of Death'] != 'Not Applicable') & 
        (df['Cause of Death'] != 'Unknown')]
df = df.reset_index(drop=True)
df
# Out:
#                 Age Tumor Location            Cancer Cell Type  \
# 0       50-79 years     Upper lobe   NSCLC-Adenocarcinoma, NOS
# 1       50-79 years     Upper lobe   NSCLC-Adenocarcinoma, NOS
# 2         85+ years     Lower lobe   NSCLC-Adenocarcinoma, NOS
# 3       50-79 years     Upper lobe         NSCLC-Squamous, NOS
# 4       50-79 years  Not Specified                Other / Rare
# ...             ...            ...                         ...
# 190933  50-79 years  Not Specified  Malignant Tumor Cells, NOS
# 190934  80-84 years  Not Specified  Malignant Tumor Cells, NOS
# 190935    85+ years  Not Specified  Malignant Tumor Cells, NOS
# 190936  50-79 years  Not Specified  Malignant Tumor Cells, NOS
# 190937  50-79 years  Not Specified  Malignant Tumor Cells, NOS
#
#                 Tumor Extent at Diagnosis Regional Lymph Node Involvement  \
# 0       Pleural Involvement/Lung Collapse          Ipsilateral Nodes Only
# 1                 Localized/Early disease            No Nodal Involvement
# 2                 Localized/Early disease            No Nodal Involvement
# 3                      Spread within Lung            No Nodal Involvement
# 4                                 Unknown             Unknown Node Status
# ...                                   ...                             ...
# 190933                            Unknown             Unknown Node Status
# 190934                            Unknown             Unknown Node Status
# 190935                            Unknown             Unknown Node Status
# 190936                            Unknown             Unknown Node Status
# 190937                            Unknown             Unknown Node Status
#
#             Metastatic Spread Tumor Laterality  \
# 0       No Distant Metastasis            Right
# 1       No Distant Metastasis            Right
# 2       No Distant Metastasis             Left
# 3       No Distant Metastasis            Right
# 4          Distant Lymph Node      Unspecified
# ...                       ...              ...
# 190933                Unknown      Unspecified
# 190934                Unknown      Unspecified
# 190935                Unknown      Unspecified
# 190936                Unknown      Unspecified
# 190937                Unknown      Unspecified
#
#        Extent of Regional Lymph Node Surgery              Treatment Plan  \
# 0                           4+ Nodes Removed  Chemotherapy after Surgery
# 1                       Unknown/Inapplicable           Unknown Treatment
# 2                           4+ Nodes Removed                     Surgery
# 3            Regional Biopsy/aspiration only  Radiotherapy after Surgery
# 4                       Unknown/Inapplicable                Chemotherapy
# ...                                      ...                         ...
# 190933                  Unknown/Inapplicable           Unknown Treatment
# 190934                  Unknown/Inapplicable           Unknown Treatment
# 190935                  Unknown/Inapplicable           Unknown Treatment
# 190936                  Unknown/Inapplicable           Unknown Treatment
# 190937                  Unknown/Inapplicable           Unknown Treatment
#
#                      Cause of Death
# 0       Alive or Not Cancer-related
# 1       Alive or Not Cancer-related
# 2       Alive or Not Cancer-related
# 3       Alive or Not Cancer-related
# 4                            Cancer
# ...                             ...
# 190933                       Cancer
# 190934                       Cancer
# 190935                       Cancer
# 190936                       Cancer
# 190937                       Cancer
#
# [190938 rows x 10 columns]

# %%
# Implement Naive Bayes for Predicting Survival Rates and Apply Cross-Validation Testing

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score, confusion_matrix

# 1. Separate features and target
X = df.drop(columns='Cause of Death')
y = df['Cause of Death']

# 2. Encode all categorical features to integers
X_encoded = X.copy()
for col in X_encoded.columns:
    le = LabelEncoder()
    X_encoded[col] = le.fit_transform(X_encoded[col].astype(str))

# 3. Encode the target as well
y_encoded = LabelEncoder().fit_transform(y.astype(str))

# 4. Set up Naive Bayes
model = CategoricalNB()

# 5. Set up k-fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
fold = 1

for train_index, test_index in kf.split(X_encoded, y_encoded):
    X_train, X_test = X_encoded.iloc[train_index], X_encoded.iloc[test_index]
    y_train, y_test = y_encoded[train_index], y_encoded[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict
    y_pred = model.predict(X_test)

    # Evaluate
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)

    print(f"Fold {fold} accuracy: {acc:.4f}")
    fold += 1

print(f"\nMean accuracy over {kf.n_splits} folds: {sum(accuracies)/kf.n_splits:.4f}")
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Fold 1 accuracy: 0.7181
# Fold 2 accuracy: 0.7187
# Fold 3 accuracy: 0.7228
# Fold 4 accuracy: 0.7195
# Fold 5 accuracy: 0.7224
#
# Mean accuracy over 5 folds: 0.7203
# Confusion matrix:
#  [[14951  6274]
#  [ 4325 12637]]

# %%
# Implement Logistic Regression for Predicting Survival Rates and Apply Cross-Validation Testing

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# 1. Separate features and target
X = df.drop(columns='Cause of Death')
y = df['Cause of Death']

# 2. One-hot encode categorical features
X_encoded = pd.get_dummies(X.astype(str), drop_first=True)

# 3. Encode target as integers
y_encoded = pd.factorize(y.astype(str))[0]

# 4. Set up logistic regression
model = LogisticRegression(max_iter=1000, solver='lbfgs', multi_class='multinomial')

# 5. Set up k-fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
fold = 1

for train_index, test_index in kf.split(X_encoded, y_encoded):
    X_train, X_test = X_encoded.iloc[train_index], X_encoded.iloc[test_index]
    y_train, y_test = y_encoded[train_index], y_encoded[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict
    y_pred = model.predict(X_test)

    # Evaluate
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)

    print(f"Fold {fold} accuracy: {acc:.4f}")
    fold += 1

print(f"\nMean accuracy over {kf.n_splits} folds: {sum(accuracies)/kf.n_splits:.4f}")
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Fold 1 accuracy: 0.7351
# Fold 2 accuracy: 0.7359
# Fold 3 accuracy: 0.7383
# Fold 4 accuracy: 0.7362
# Fold 5 accuracy: 0.7375
#
# Mean accuracy over 5 folds: 0.7366
# Confusion matrix:
#  [[16089  5136]
#  [ 4888 12074]]
